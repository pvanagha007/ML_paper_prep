# %%
import pandas as pd
iris=pd.read_csv("D:\Anagha\Paper\ML_PAPER_PREP\iris.csv")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
len=iris["sepal_length"] #to call as a dict
#or iris.sepal_length for native accessors
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#to select first val of species col
spec=iris["species"][0]
spec
# Out:
# 'setosa'

# %%
#to select first row using advanced accessors
row=iris.iloc[0]
row
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
#to select first 10 values from the col --> species
val=iris.loc[0:9,"species"]
val
# Out:
# 0    setosa
# 1    setosa
# 2    setosa
# 3    setosa
# 4    setosa
# 5    setosa
# 6    setosa
# 7    setosa
# 8    setosa
# 9    setosa
# Name: species, dtype: object

# %%
iris.head(50)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
rev=iris.loc[iris.petal_width==0.1]
rev
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 9            4.9          3.1           1.5          0.1  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# 13           4.3          3.0           1.1          0.1  setosa
# 32           5.2          4.1           1.5          0.1  setosa
# 37           4.9          3.6           1.4          0.1  setosa

# %%
#to get specific indices
indices = [1, 2, 3, 5, 8]
sample_iris = iris.loc[indices]
sample_iris
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 8           4.4          2.9           1.4          0.2  setosa

# %%
#to get specific rows and cols
cols = ['sepal_length','species']
indices = [0, 1, 10, 100]
df = iris.loc[indices, cols]
df
# Out:
#      sepal_length    species
# 0             5.1     setosa
# 1             4.9     setosa
# 10            5.4     setosa
# 100           6.3  virginica
