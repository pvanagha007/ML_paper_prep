# %%
import numpy as np
a=np.arange(40,100,3).reshape(4,5)
print(a)
# Out:
# [[40 43 46 49 52]
#  [55 58 61 64 67]
#  [70 73 76 79 82]
#  [85 88 91 94 97]]

# %%
a[1,2]
# Out:
# np.int64(61)

# %%
a[::-1, ::-1]
# Out:
# array([[97, 94, 91, 88, 85],
#        [82, 79, 76, 73, 70],
#        [67, 64, 61, 58, 55],
#        [52, 49, 46, 43, 40]])

# %%
a[:,1]
# Out:
# array([43, 58, 73, 88])

# %%
a[0, :]
# Out:
# array([40, 43, 46, 49, 52])

# %%
a[:,:]
# Out:
# array([[40, 43, 46, 49, 52],
#        [55, 58, 61, 64, 67],
#        [70, 73, 76, 79, 82],
#        [85, 88, 91, 94, 97]])

# %%
a[::2,::2]=10000
print(a)
# Out:
# [[10000    43 10000    49 10000]
#  [   55    58    61    64    67]
#  [10000    73 10000    79 10000]
#  [   85    88    91    94    97]]
